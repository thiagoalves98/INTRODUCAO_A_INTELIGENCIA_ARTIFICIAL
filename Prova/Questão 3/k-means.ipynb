# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Live.csv')
#df

# %%
df = df.drop(df.iloc[:,12:], axis = 1)

# %%
df = df.drop('status_id', axis = 1)

df = df.drop_duplicates()

#df

# %%
df.drop([498, 480, 6703, 3246, 6762, 6799, 6659, 6448], axis = 0 ,inplace = True)

ver = df['num_reactions'] != (df['num_likes'] + df['num_loves'] + df['num_wows'] + df['num_hahas'] + df['num_sads'] + df['num_angrys'])
#Quantidade de instâncias com dados inconsistentes
len(df[ver])

df.drop(df[ver].index, axis = 0, inplace = True)

df.drop('num_reactions', axis = 1, inplace = True)

df = df.reset_index()
df.drop("index", axis = 1, inplace = True)

df.drop("status_published", axis = 1, inplace = True)

x = df
saida = df['status_type']

from sklearn.preprocessing import LabelEncoder

status_type = LabelEncoder().fit_transform(df['status_type'])
df['status_type'] = status_type

df
# Out:
#       status_type  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0               3           512         262        432         92         3
# 1               1             0           0        150          0         0
# 2               3           236          57        204         21         1
# 3               1             0           0        111          0         0
# 4               1             0           0        204          9         0
# ...           ...           ...         ...        ...        ...       ...
# 6974            1             0           0         89          0         0
# 6975            1             0           0         14          1         0
# 6976            1             0           0          1          1         0
# 6977            1            12          22        349          2         0
# 6978            1             0           0         17          0         0
#
#       num_hahas  num_sads  num_angrys
# 0             1         1           0
# 1             0         0           0
# 2             1         0           0
# 3             0         0           0
# 4             0         0           0
# ...         ...       ...         ...
# 6974          0         0           0
# 6975          1         0           0
# 6976          0         0           0
# 6977          0         0           0
# 6978          0         0           0
#
# [6979 rows x 9 columns]

# %%
from sklearn.cluster import AgglomerativeClustering

hc = AgglomerativeClustering(n_clusters = 15, affinity = 'euclidean', linkage = 'single')
y_hc = hc.fit_predict(x)

a = pd.DataFrame(y_hc)
lista = list(a[0].value_counts())
#pd.DataFrame(lista, columns=["nInstancias"])

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 15, affinity = 'euclidean', linkage = 'complete')
y_hc = hc.fit_predict(x)

a = pd.DataFrame(y_hc)
lista = list(a[0].value_counts())
pd.DataFrame(lista, columns=["nInstancias"])
# Out:
#     nInstancias
# 0          6288
# 1           239
# 2           158
# 3           101
# 4            53
# 5            28
# 6            25
# 7            24
# 8            23
# 9            15
# 10           13
# 11            6
# 12            4
# 13            1
# 14            1

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=15, random_state= 15).fit(x)
a = pd.DataFrame(kmeans.labels_)
lista = list(a[0].value_counts())
pd.DataFrame(lista, columns=["nInstancias"])
# Out:
#     nInstancias
# 0          4772
# 1           771
# 2           451
# 3           226
# 4           223
# 5           181
# 6           101
# 7            57
# 8            52
# 9            50
# 10           35
# 11           26
# 12           22
# 13           11
# 14            1
